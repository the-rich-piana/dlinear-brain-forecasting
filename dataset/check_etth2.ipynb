# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('ETTh2.csv')

# %%
df.values[:,1]
# Out:
# array([41.13000106811523, 37.52799987792969, 37.946998596191406, ...,
#        39.62200164794922, 43.64300155639648, 38.86800003051758],
#       dtype=object)

# %%
sns.lineplot(df.values[:,1])
# Out:
# <Axes: >
